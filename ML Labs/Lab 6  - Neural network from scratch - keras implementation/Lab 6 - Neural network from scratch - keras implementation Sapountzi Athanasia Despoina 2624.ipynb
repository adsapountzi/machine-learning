# %%
from jyquickhelper import add_notebook_menu
add_notebook_menu()
# Out:
# <div id="my_id_menu_nb">run previous cell, wait for 2 seconds</div>
# <script>
# function repeat_indent_string(n){
#     var a = "" ;
#     for ( ; n > 0 ; --n)
#         a += "    ";
#     return a;
# }
# // look up into all sections and builds an automated menu //
# var update_menu_string = function(begin, lfirst, llast, sformat, send, keep_item, begin_format, end_format) {
#     var anchors = document.getElementsByClassName("section");
#     if (anchors.length == 0) {
#         anchors = document.getElementsByClassName("text_cell_render rendered_html");
#     }
#     var i,t;
#     var text_menu = begin;
#     var text_memo = "<pre>\nlength:" + anchors.length + "\n";
#     var ind = "";
#     var memo_level = 1;
#     var href;
#     var tags = [];
#     var main_item = 0;
#     var format_open = 0;
#     for (i = 0; i <= llast; i++)
#         tags.push("h" + i);
#
#     for (i = 0; i < anchors.length; i++) {
#         text_memo += "**" + anchors[i].id + "--\n";
#
#         var child = null;
#         for(t = 0; t < tags.length; t++) {
#             var r = anchors[i].getElementsByTagName(tags[t]);
#             if (r.length > 0) {
# child = r[0];
# break;
#             }
#         }
#         if (child == null) {
#             text_memo += "null\n";
#             continue;
#         }
#         if (anchors[i].hasAttribute("id")) {
#             // when converted in RST
#             href = anchors[i].id;
#             text_memo += "#1-" + href;
#             // passer à child suivant (le chercher)
#         }
#         else if (child.hasAttribute("id")) {
#             // in a notebook
#             href = child.id;
#             text_memo += "#2-" + href;
#         }
#         else {
#             text_memo += "#3-" + "*" + "\n";
#             continue;
#         }
#         var title = child.textContent;
#         var level = parseInt(child.tagName.substring(1,2));
#
#         text_memo += "--" + level + "?" + lfirst + "--" + title + "\n";
#
#         if ((level < lfirst) || (level > llast)) {
#             continue ;
#         }
#         if (title.endsWith('¶')) {
#             title = title.substring(0,title.length-1).replace("<", "&lt;")
#          .replace(">", "&gt;").replace("&", "&amp;");
#         }
#         if (title.length == 0) {
#             continue;
#         }
#
#         while (level < memo_level) {
#             text_menu += end_format + "</ul>\n";
#             format_open -= 1;
#             memo_level -= 1;
#         }
#         if (level == lfirst) {
#             main_item += 1;
#         }
#         if (keep_item != -1 && main_item != keep_item + 1) {
#             // alert(main_item + " - " + level + " - " + keep_item);
#             continue;
#         }
#         while (level > memo_level) {
#             text_menu += "<ul>\n";
#             memo_level += 1;
#         }
#         text_menu += repeat_indent_string(level-2);
#         text_menu += begin_format + sformat.replace("__HREF__", href).replace("__TITLE__", title);
#         format_open += 1;
#     }
#     while (1 < memo_level) {
#         text_menu += end_format + "</ul>\n";
#         memo_level -= 1;
#         format_open -= 1;
#     }
#     text_menu += send;
#     //text_menu += "\n" + text_memo;
#
#     while (format_open > 0) {
#         text_menu += end_format;
#         format_open -= 1;
#     }
#     return text_menu;
# };
# var update_menu = function() {
#     var sbegin = "";
#     var sformat = '<a href="#__HREF__">__TITLE__</a>';
#     var send = "";
#     var begin_format = '<li>';
#     var end_format = '</li>';
#     var keep_item = -1;
#     var text_menu = update_menu_string(sbegin, 2, 4, sformat, send, keep_item,
#        begin_format, end_format);
#     var menu = document.getElementById("my_id_menu_nb");
#     menu.innerHTML=text_menu;
# };
# window.setTimeout(update_menu,2000);
#             </script>

# %% [markdown]
# \begin{exercise}
#
# Implement the  neural network example in this notebook with keras
#
# \end{exercise}

# %% [markdown]
# # exercise

# %%
import tensorflow as tf
from tensorflow import keras

# %%
from tensorflow.python.keras.layers import Input, Dense
from tensorflow.python.keras.models import Sequential

# %%
def unknown_function(X):
    coeff = np.array([[2., -1., 5.]])
    return np.dot(X, coeff.T)

X = np.array([
    [4.,9.,1.],
    [2.,5.,6.],
    [1.,8.,3.]
])

t = unknown_function(X) # target
print(t)
# Out:
# [[ 4.]
#  [29.]
#  [ 9.]]

# %%
model = tf.keras.Sequential([
  tf.keras.layers.Dense(2, activation='tanh',input_dim=3),  # input required
#   tf.keras.layers.Dense(10, activation="relu"),
  tf.keras.layers.Dense(1)
])
print(model.summary())
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_20 (Dense)             (None, 2)                 8
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 11
# Trainable params: 11
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Model compilation
# model.compile(loss='mean_squared_error', optimizer='adam')
#SGD better optimizer than adam for our data
model.compile(optimizer='SGD',loss='mean_squared_error')

# %%
def loss(model, x, y):
  y_ = model(x)
  return tf.losses.sparse_softmax_cross_entropy(labels=y, logits=y_)


def grad(model, inputs, targets):
  with tf.GradientTape() as tape:
    loss_value = loss(model, inputs, targets)
  return tape.gradient(loss_value, model.variables)

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)

# %%
import tensorflow.contrib.eager as tfe
## tensorflow.contrib doesn't exist in 2.0.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-154-e6c1000ade32> in <module>
# ----> 1 import tensorflow.contrib.eager as tfe
#       2 ## tensorflow.contrib doesn't exist in 2.0.
#
# ModuleNotFoundError: No module named 'tensorflow.contrib'

# %%
model.fit(X , t, epochs=1000)
# Out:
# Train on 3 samples
# Epoch 1/1000
# 3/3 [==============================] - 0s 49ms/sample - loss: 352.1177
# Epoch 2/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 316.8711
# Epoch 3/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 293.6925
# Epoch 4/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 273.1480
# Epoch 5/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 254.9783
# Epoch 6/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 238.9169
# Epoch 7/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 224.7204
# Epoch 8/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 212.1718
# Epoch 9/1000
# 3/3 [==============================] - 0s 3ms/sample - loss: 201.0793
# Epoch 10/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 191.2738
# Epoch 11/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 182.6060
# Epoch 12/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 174.9443
# Epoch 13/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 168.1720
# Epoch 14/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 162.1864
# Epoch 15/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 156.8962
# Epoch 16/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 152.2207
# Epoch 17/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 148.0887
# Epoch 18/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 144.4370
# Epoch 19/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 141.2099
# Epoch 20/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 138.3580
# Epoch 21/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 135.8376
# Epoch 22/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 133.6104
# Epoch 23/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 131.6422
# Epoch 24/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 129.9029
# Epoch 25/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 128.3658
# Epoch 26/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 127.0075
# Epoch 27/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 125.8072
# Epoch 28/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 124.7464
# Epoch 29/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 123.8090
# Epoch 30/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 122.9806
# Epoch 31/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 122.2485
# Epoch 32/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 121.6015
# Epoch 33/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 121.0298
# Epoch 34/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 120.5245
# Epoch 35/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 120.0780
# Epoch 36/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 119.6833
# Epoch 37/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 119.3346
# Epoch 38/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 119.0264
# Epoch 39/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 118.7540
# Epoch 40/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 118.5132
# Epoch 41/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 118.3004
# Epoch 42/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 118.1123
# Epoch 43/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 117.9461
# Epoch 44/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 117.7992
# Epoch 45/1000
# 3/3 [==============================] - 0s 1000us/sample - loss: 117.6693
# Epoch 46/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 117.5545
# Epoch 47/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 117.4531
# Epoch 48/1000
# 3/3 [==============================] - 0s 995us/sample - loss: 117.3634
# Epoch 49/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 117.2841
# Epoch 50/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 117.2140
# Epoch 51/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 117.1520
# Epoch 52/1000
# 3/3 [==============================] - 0s 996us/sample - loss: 117.0972
# Epoch 53/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 117.0488
# Epoch 54/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 117.0059
# Epoch 55/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.9681
# Epoch 56/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.9346
# Epoch 57/1000
# 3/3 [==============================] - 0s 664us/sample - loss: 116.9049
# Epoch 58/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.8787
# Epoch 59/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.8556
# Epoch 60/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.8351
# Epoch 61/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.8169
# Epoch 62/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.8008
# Epoch 63/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.7866
# Epoch 64/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.7741
# Epoch 65/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.7629
# Epoch 66/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.7531
# Epoch 67/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.7443
# Epoch 68/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.7366
# Epoch 69/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.7298
# Epoch 70/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.7237
# Epoch 71/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.7183
# Epoch 72/1000
# 3/3 [==============================] - 0s 994us/sample - loss: 116.7135
# Epoch 73/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.7093
# Epoch 74/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.7055
# Epoch 75/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.7022
# Epoch 76/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6992
# Epoch 77/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6966
# Epoch 78/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6942
# Epoch 79/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6921
# Epoch 80/1000
# 3/3 [==============================] - 0s 5ms/sample - loss: 116.6903
# Epoch 81/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6886
# Epoch 82/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6872
# Epoch 83/1000
# 3/3 [==============================] - 0s 4ms/sample - loss: 116.6859
# Epoch 84/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6847
# Epoch 85/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6836
# Epoch 86/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6827
# Epoch 87/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6818
# Epoch 88/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6811
# Epoch 89/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6804
# Epoch 90/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6798
# Epoch 91/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6793
# Epoch 92/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6787
# Epoch 93/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6783
# Epoch 94/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6779
# Epoch 95/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6775
# Epoch 96/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6772
# Epoch 97/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6769
# Epoch 98/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6766
# Epoch 99/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6763
# Epoch 100/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6761
# Epoch 101/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6759
# Epoch 102/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6757
# Epoch 103/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6755
# Epoch 104/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6753
# Epoch 105/1000
# 3/3 [==============================] - 0s 666us/sample - loss: 116.6751
# Epoch 106/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6750
# Epoch 107/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6749
# Epoch 108/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6747
# Epoch 109/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6746
# Epoch 110/1000
# 3/3 [==============================] - 0s 994us/sample - loss: 116.6745
# Epoch 111/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6744
# Epoch 112/1000
# 3/3 [==============================] - 0s 999us/sample - loss: 116.6743
# Epoch 113/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6742
# Epoch 114/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6741
# Epoch 115/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6740
# Epoch 116/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6739
# Epoch 117/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6738
# Epoch 118/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6737
# Epoch 119/1000
# 3/3 [==============================] - 0s 1000us/sample - loss: 116.6737
# Epoch 120/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6736
# Epoch 121/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6735
# Epoch 122/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6735
# Epoch 123/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6734
# Epoch 124/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6733
# Epoch 125/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6732
# Epoch 126/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6732
# Epoch 127/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6731
# Epoch 128/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6731
# Epoch 129/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6730
# Epoch 130/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6730
# Epoch 131/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6729
# Epoch 132/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6728
# Epoch 133/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6728
# Epoch 134/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6728
# Epoch 135/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6727
# Epoch 136/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6726
# Epoch 137/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6726
# Epoch 138/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6725
# Epoch 139/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6725
# Epoch 140/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6725
# Epoch 141/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6724
# Epoch 142/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6724
# Epoch 143/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6723
# Epoch 144/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6723
# Epoch 145/1000
# 3/3 [==============================] - 0s 994us/sample - loss: 116.6722
# Epoch 146/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6722
# Epoch 147/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6722
# Epoch 148/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6721
# Epoch 149/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6721
# Epoch 150/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6721
# Epoch 151/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6720
# Epoch 152/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6720
# Epoch 153/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6719
# Epoch 154/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6719
# Epoch 155/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6719
# Epoch 156/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6718
# Epoch 157/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6718
# Epoch 158/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6717
# Epoch 159/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6717
# Epoch 160/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6717
# Epoch 161/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6717
# Epoch 162/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6716
# Epoch 163/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6716
# Epoch 164/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6715
# Epoch 165/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6715
# Epoch 166/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6715
# Epoch 167/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6715
# Epoch 168/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6714
# Epoch 169/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6714
# Epoch 170/1000
# 3/3 [==============================] - 0s 667us/sample - loss: 116.6714
# Epoch 171/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6714
# Epoch 172/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6713
# Epoch 173/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6713
# Epoch 174/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6712
# Epoch 175/1000
# 3/3 [==============================] - ETA: 0s - loss: 116.671 - 0s 997us/sample - loss: 116.6712
# Epoch 176/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6712
# Epoch 177/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6712
# Epoch 178/1000
# 3/3 [==============================] - 0s 995us/sample - loss: 116.6711
# Epoch 179/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6711
# Epoch 180/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6711
# Epoch 181/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6711
# Epoch 182/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6710
# Epoch 183/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6710
# Epoch 184/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6710
# Epoch 185/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6710
# Epoch 186/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6710
# Epoch 187/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6709
# Epoch 188/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6709
# Epoch 189/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6709
# Epoch 190/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6708
# Epoch 191/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6708
# Epoch 192/1000
# 3/3 [==============================] - 0s 994us/sample - loss: 116.6708
# Epoch 193/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6708
# Epoch 194/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6708
# Epoch 195/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6708
# Epoch 196/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6707
# Epoch 197/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6707
# Epoch 198/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6707
# Epoch 199/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6706
# Epoch 200/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6706
# Epoch 201/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6706
# Epoch 202/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6706
# Epoch 203/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6706
# Epoch 204/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6705
# Epoch 205/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6705
# Epoch 206/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6705
# Epoch 207/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6705
# Epoch 208/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6705
# Epoch 209/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6705
# Epoch 210/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6704
# Epoch 211/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6704
# Epoch 212/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6704
# Epoch 213/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6704
# Epoch 214/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6703
# Epoch 215/1000
# 3/3 [==============================] - 0s 996us/sample - loss: 116.6703
# Epoch 216/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6703
# Epoch 217/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6703
# Epoch 218/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6703
# Epoch 219/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6703
# Epoch 220/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6702
# Epoch 221/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6702
# Epoch 222/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6702
# Epoch 223/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6702
# Epoch 224/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6702
# Epoch 225/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6702
# Epoch 226/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6702
# Epoch 227/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6701
# Epoch 228/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6701
# Epoch 229/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6701
# Epoch 230/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6701
# Epoch 231/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6701
# Epoch 232/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6701
# Epoch 233/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6700
# Epoch 234/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6700
# Epoch 235/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6700
# Epoch 236/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6700
# Epoch 237/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6700
# Epoch 238/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6700
# Epoch 239/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6700
# Epoch 240/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6700
# Epoch 241/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6699
# Epoch 242/1000
# 3/3 [==============================] - 0s 999us/sample - loss: 116.6699
# Epoch 243/1000
# 3/3 [==============================] - 0s 3ms/sample - loss: 116.6699
# Epoch 244/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6699
# Epoch 245/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6699
# Epoch 246/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6699
# Epoch 247/1000
# 3/3 [==============================] - 0s 3ms/sample - loss: 116.6698
# Epoch 248/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6698
# Epoch 249/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6698
# Epoch 250/1000
# 3/3 [==============================] - 0s 3ms/sample - loss: 116.6698
# Epoch 251/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6698
# Epoch 252/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6698
# Epoch 253/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6698
# Epoch 254/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6698
# Epoch 255/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6697
# Epoch 256/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6697
# Epoch 257/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6697
# Epoch 258/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6697
# Epoch 259/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6697
# Epoch 260/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6697
# Epoch 261/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6697
# Epoch 262/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6697
# Epoch 263/1000
# 3/3 [==============================] - 0s 999us/sample - loss: 116.6696
# Epoch 264/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6696
# Epoch 265/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6696
# Epoch 266/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6696
# Epoch 267/1000
# 3/3 [==============================] - 0s 994us/sample - loss: 116.6696
# Epoch 268/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6696
# Epoch 269/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6696
# Epoch 270/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6695
# Epoch 271/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6695
# Epoch 272/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6696
# Epoch 273/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6695
# Epoch 274/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6695
# Epoch 275/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6695
# Epoch 276/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6695
# Epoch 277/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6695
# Epoch 278/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6695
# Epoch 279/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6695
# Epoch 280/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6695
# Epoch 281/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6695
# Epoch 282/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6694
# Epoch 283/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6694
# Epoch 284/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6694
# Epoch 285/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6694
# Epoch 286/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6694
# Epoch 287/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6694
# Epoch 288/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6694
# Epoch 289/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6694
# Epoch 290/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6693
# Epoch 291/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6693
# Epoch 292/1000
# 3/3 [==============================] - 0s 996us/sample - loss: 116.6693
# Epoch 293/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6693
# Epoch 294/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6693
# Epoch 295/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6693
# Epoch 296/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6693
# Epoch 297/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6693
# Epoch 298/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6693
# Epoch 299/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6693
# Epoch 300/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6693
# Epoch 301/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6693
# Epoch 302/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6693
# Epoch 303/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6692
# Epoch 304/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6692
# Epoch 305/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6692
# Epoch 306/1000
# 3/3 [==============================] - 0s 996us/sample - loss: 116.6692
# Epoch 307/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6692
# Epoch 308/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6692
# Epoch 309/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6692
# Epoch 310/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6692
# Epoch 311/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6692
# Epoch 312/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6692
# Epoch 313/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6692
# Epoch 314/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6692
# Epoch 315/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6691
# Epoch 316/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6691
# Epoch 317/1000
# 3/3 [==============================] - 0s 5ms/sample - loss: 116.6691
# Epoch 318/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6691
# Epoch 319/1000
# 3/3 [==============================] - 0s 994us/sample - loss: 116.6691
# Epoch 320/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6691
# Epoch 321/1000
# 3/3 [==============================] - 0s 994us/sample - loss: 116.6691
# Epoch 322/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6691
# Epoch 323/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6691
# Epoch 324/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6691
# Epoch 325/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6690
# Epoch 326/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6691
# Epoch 327/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6690
# Epoch 328/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6690
# Epoch 329/1000
# 3/3 [==============================] - 0s 7ms/sample - loss: 116.6690
# Epoch 330/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6690
# Epoch 331/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6690
# Epoch 332/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6690
# Epoch 333/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6690
# Epoch 334/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6690
# Epoch 335/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6690
# Epoch 336/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6690
# Epoch 337/1000
# 3/3 [==============================] - 0s 659us/sample - loss: 116.6690
# Epoch 338/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6689
# Epoch 339/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6690
# Epoch 340/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6690
# Epoch 341/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6689
# Epoch 342/1000
# 3/3 [==============================] - 0s 3ms/sample - loss: 116.6689
# Epoch 343/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6689
# Epoch 344/1000
# 3/3 [==============================] - 0s 1000us/sample - loss: 116.6689
# Epoch 345/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6689
# Epoch 346/1000
# 3/3 [==============================] - 0s 992us/sample - loss: 116.6689
# Epoch 347/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6689
# Epoch 348/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6689
# Epoch 349/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6689
# Epoch 350/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6689
# Epoch 351/1000
# 3/3 [==============================] - 0s 992us/sample - loss: 116.6689
# Epoch 352/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6689
# Epoch 353/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6689
# Epoch 354/1000
# 3/3 [==============================] - 0s 6ms/sample - loss: 116.6689
# Epoch 355/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6689
# Epoch 356/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6688
# Epoch 357/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6689
# Epoch 358/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6688
# Epoch 359/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6688
# Epoch 360/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6688
# Epoch 361/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6688
# Epoch 362/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6688
# Epoch 363/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6688
# Epoch 364/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6688
# Epoch 365/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6688
# Epoch 366/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6688
# Epoch 367/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6688
# Epoch 368/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6688
# Epoch 369/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6688
# Epoch 370/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6688
# Epoch 371/1000
# 3/3 [==============================] - 0s 3ms/sample - loss: 116.6688
# Epoch 372/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6688
# Epoch 373/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6688
# Epoch 374/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6688
# Epoch 375/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6687
# Epoch 376/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6687
# Epoch 377/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6687
# Epoch 378/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6687
# Epoch 379/1000
# 3/3 [==============================] - 0s 995us/sample - loss: 116.6687
# Epoch 380/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6687
# Epoch 381/1000
# 3/3 [==============================] - 0s 3ms/sample - loss: 116.6687
# Epoch 382/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6687
# Epoch 383/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6687
# Epoch 384/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6687
# Epoch 385/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6687
# Epoch 386/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6687
# Epoch 387/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6687
# Epoch 388/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6686
# Epoch 389/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6686
# Epoch 390/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6686
# Epoch 391/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6686
# Epoch 392/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6686
# Epoch 393/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6686
# Epoch 394/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6686
# Epoch 395/1000
# 3/3 [==============================] - 0s 999us/sample - loss: 116.6686
# Epoch 396/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6686
# Epoch 397/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6686
# Epoch 398/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6686
# Epoch 399/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6686
# Epoch 400/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6686
# Epoch 401/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6686
# Epoch 402/1000
# 3/3 [==============================] - 0s 6ms/sample - loss: 116.6686
# Epoch 403/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6686
# Epoch 404/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6686
# Epoch 405/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6686
# Epoch 406/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6686
# Epoch 407/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6686
# Epoch 408/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6686
# Epoch 409/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6686
# Epoch 410/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6685
# Epoch 411/1000
# 3/3 [==============================] - 0s 995us/sample - loss: 116.6686
# Epoch 412/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6686
# Epoch 413/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6685
# Epoch 414/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6685
# Epoch 415/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6685
# Epoch 416/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6685
# Epoch 417/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6685
# Epoch 418/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6685
# Epoch 419/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6685
# Epoch 420/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6685
# Epoch 421/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6685
# Epoch 422/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6685
# Epoch 423/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6685
# Epoch 424/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6685
# Epoch 425/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6685
# Epoch 426/1000
# 3/3 [==============================] - 0s 3ms/sample - loss: 116.6685
# Epoch 427/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6685
# Epoch 428/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6685
# Epoch 429/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6685
# Epoch 430/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6685
# Epoch 431/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6685
# Epoch 432/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6685
# Epoch 433/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6684
# Epoch 434/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6684
# Epoch 435/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6684
# Epoch 436/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6684
# Epoch 437/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6684
# Epoch 438/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6684
# Epoch 439/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6684
# Epoch 440/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6684
# Epoch 441/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6684
# Epoch 442/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6684
# Epoch 443/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6684
# Epoch 444/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6684
# Epoch 445/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6684
# Epoch 446/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6684
# Epoch 447/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6684
# Epoch 448/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6684
# Epoch 449/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6684
# Epoch 450/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6684
# Epoch 451/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6684
# Epoch 452/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6684
# Epoch 453/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6684
# Epoch 454/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6684
# Epoch 455/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6684
# Epoch 456/1000
# 3/3 [==============================] - 0s 3ms/sample - loss: 116.6684
# Epoch 457/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6684
# Epoch 458/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6684
# Epoch 459/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6683
# Epoch 460/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6683
# Epoch 461/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6683
# Epoch 462/1000
# 3/3 [==============================] - 0s 3ms/sample - loss: 116.6683
# Epoch 463/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6683
# Epoch 464/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6683
# Epoch 465/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6683
# Epoch 466/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6683
# Epoch 467/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6683
# Epoch 468/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6683
# Epoch 469/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6683
# Epoch 470/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6683
# Epoch 471/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6683
# Epoch 472/1000
# 3/3 [==============================] - 0s 993us/sample - loss: 116.6683
# Epoch 473/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6683
# Epoch 474/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6683
# Epoch 475/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6683
# Epoch 476/1000
# 3/3 [==============================] - 0s 999us/sample - loss: 116.6683
# Epoch 477/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6683
# Epoch 478/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6683
# Epoch 479/1000
# 3/3 [==============================] - 0s 991us/sample - loss: 116.6683
# Epoch 480/1000
# 3/3 [==============================] - 0s 5ms/sample - loss: 116.6683
# Epoch 481/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6683
# Epoch 482/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6683
# Epoch 483/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6683
# Epoch 484/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6683
# Epoch 485/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6683
# Epoch 486/1000
# 3/3 [==============================] - 0s 999us/sample - loss: 116.6683
# Epoch 487/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6683
# Epoch 488/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6682
# Epoch 489/1000
# 3/3 [==============================] - 0s 3ms/sample - loss: 116.6682
# Epoch 490/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6682
# Epoch 491/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6683
# Epoch 492/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6682
# Epoch 493/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6682
# Epoch 494/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6682
# Epoch 495/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6682
# Epoch 496/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6682
# Epoch 497/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6682
# Epoch 498/1000
# 3/3 [==============================] - 0s 995us/sample - loss: 116.6682
# Epoch 499/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6682
# Epoch 500/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6682
# Epoch 501/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6682
# Epoch 502/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6682
# Epoch 503/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6682
# Epoch 504/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6682
# Epoch 505/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6682
# Epoch 506/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6682
# Epoch 507/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6682
# Epoch 508/1000
# 3/3 [==============================] - 0s 995us/sample - loss: 116.6682
# Epoch 509/1000
# 3/3 [==============================] - 0s 3ms/sample - loss: 116.6682
# Epoch 510/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6682
# Epoch 511/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6682
# Epoch 512/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6682
# Epoch 513/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6682
# Epoch 514/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6682
# Epoch 515/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6682
# Epoch 516/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6682
# Epoch 517/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6682
# Epoch 518/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6682
# Epoch 519/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6682
# Epoch 520/1000
# 3/3 [==============================] - 0s 999us/sample - loss: 116.6681
# Epoch 521/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6682
# Epoch 522/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6681
# Epoch 523/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6681
# Epoch 524/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6681
# Epoch 525/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6681
# Epoch 526/1000
# 3/3 [==============================] - 0s 996us/sample - loss: 116.6681
# Epoch 527/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6681
# Epoch 528/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6681
# Epoch 529/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6681
# Epoch 530/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6681
# Epoch 531/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6681
# Epoch 532/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6681
# Epoch 533/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6681
# Epoch 534/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6681
# Epoch 535/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6681
# Epoch 536/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6681
# Epoch 537/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6681
# Epoch 538/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6681
# Epoch 539/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6681
# Epoch 540/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6681
# Epoch 541/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6681
# Epoch 542/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6681
# Epoch 543/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6681
# Epoch 544/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6681
# Epoch 545/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6681
# Epoch 546/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6681
# Epoch 547/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6681
# Epoch 548/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6681
# Epoch 549/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6681
# Epoch 550/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6681
# Epoch 551/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6681
# Epoch 552/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6681
# Epoch 553/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6680
# Epoch 554/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6681
# Epoch 555/1000
# 3/3 [==============================] - 0s 10ms/sample - loss: 116.6680
# Epoch 556/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6681
# Epoch 557/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6680
# Epoch 558/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6681
# Epoch 559/1000
# ...
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6676
# Epoch 816/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6676
# Epoch 817/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6676
# Epoch 818/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6676
# Epoch 819/1000
# 3/3 [==============================] - 0s 996us/sample - loss: 116.6676
# Epoch 820/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6676
# Epoch 821/1000
# 3/3 [==============================] - 0s 979us/sample - loss: 116.6676
# Epoch 822/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6676
# Epoch 823/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6676
# Epoch 824/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6676
# Epoch 825/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6676
# Epoch 826/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6676
# Epoch 827/1000
# 3/3 [==============================] - 0s 1000us/sample - loss: 116.6676
# Epoch 828/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6676
# Epoch 829/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6676
# Epoch 830/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6676
# Epoch 831/1000
# 3/3 [==============================] - 0s 990us/sample - loss: 116.6676
# Epoch 832/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6676
# Epoch 833/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6676
# Epoch 834/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6676
# Epoch 835/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6676
# Epoch 836/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6676
# Epoch 837/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6676
# Epoch 838/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6676
# Epoch 839/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6676
# Epoch 840/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6676
# Epoch 841/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6676
# Epoch 842/1000
# 3/3 [==============================] - 0s 666us/sample - loss: 116.6676
# Epoch 843/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6676
# Epoch 844/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6676
# Epoch 845/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6676
# Epoch 846/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6676
# Epoch 847/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6676
# Epoch 848/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6676
# Epoch 849/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6676
# Epoch 850/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6676
# Epoch 851/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6676
# Epoch 852/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6676
# Epoch 853/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6676
# Epoch 854/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6676
# Epoch 855/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6675
# Epoch 856/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6676
# Epoch 857/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6676
# Epoch 858/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6676
# Epoch 859/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 860/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 861/1000
# 3/3 [==============================] - 0s 996us/sample - loss: 116.6675
# Epoch 862/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6675
# Epoch 863/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6675
# Epoch 864/1000
# 3/3 [==============================] - 0s 664us/sample - loss: 116.6675
# Epoch 865/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6675
# Epoch 866/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6676
# Epoch 867/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 868/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6675
# Epoch 869/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6675
# Epoch 870/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6675
# Epoch 871/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6675
# Epoch 872/1000
# 3/3 [==============================] - 0s 666us/sample - loss: 116.6675
# Epoch 873/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6675
# Epoch 874/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 875/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 876/1000
# 3/3 [==============================] - 0s 995us/sample - loss: 116.6675
# Epoch 877/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6675
# Epoch 878/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6675
# Epoch 879/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6675
# Epoch 880/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6675
# Epoch 881/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6675
# Epoch 882/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 883/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6675
# Epoch 884/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6675
# Epoch 885/1000
# 3/3 [==============================] - 0s 996us/sample - loss: 116.6675
# Epoch 886/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6675
# Epoch 887/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 888/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6675
# Epoch 889/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6675
# Epoch 890/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 891/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 892/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 893/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6675
# Epoch 894/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 895/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6675
# Epoch 896/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6675
# Epoch 897/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6675
# Epoch 898/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6675
# Epoch 899/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6675
# Epoch 900/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6675
# Epoch 901/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6675
# Epoch 902/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6675
# Epoch 903/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6675
# Epoch 904/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6675
# Epoch 905/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 906/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6675
# Epoch 907/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 908/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6675
# Epoch 909/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6675
# Epoch 910/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6675
# Epoch 911/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6675
# Epoch 912/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6675
# Epoch 913/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6675
# Epoch 914/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6675
# Epoch 915/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6675
# Epoch 916/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 917/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6675
# Epoch 918/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6675
# Epoch 919/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 920/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 921/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6675
# Epoch 922/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6675
# Epoch 923/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 924/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6675
# Epoch 925/1000
# 3/3 [==============================] - 0s 999us/sample - loss: 116.6675
# Epoch 926/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6675
# Epoch 927/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 928/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6675
# Epoch 929/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 930/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 931/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6675
# Epoch 932/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6675
# Epoch 933/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 934/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 935/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6675
# Epoch 936/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6675
# Epoch 937/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 938/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 939/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6675
# Epoch 940/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 941/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6675
# Epoch 942/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 943/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6675
# Epoch 944/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 945/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6675
# Epoch 946/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 947/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 948/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6675
# Epoch 949/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 950/1000
# 3/3 [==============================] - 0s 3ms/sample - loss: 116.6675
# Epoch 951/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6675
# Epoch 952/1000
# 3/3 [==============================] - 0s 664us/sample - loss: 116.6675
# Epoch 953/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6675
# Epoch 954/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6675
# Epoch 955/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 956/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6674
# Epoch 957/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6675
# Epoch 958/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 959/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6674
# Epoch 960/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6674
# Epoch 961/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6675
# Epoch 962/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6675
# Epoch 963/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6674
# Epoch 964/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6674
# Epoch 965/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6674
# Epoch 966/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6675
# Epoch 967/1000
# 3/3 [==============================] - 0s 999us/sample - loss: 116.6674
# Epoch 968/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6674
# Epoch 969/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6674
# Epoch 970/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6675
# Epoch 971/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6674
# Epoch 972/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6674
# Epoch 973/1000
# 3/3 [==============================] - 0s 665us/sample - loss: 116.6674
# Epoch 974/1000
# 3/3 [==============================] - 0s 995us/sample - loss: 116.6674
# Epoch 975/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6674
# Epoch 976/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6674
# Epoch 977/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6674
# Epoch 978/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6674
# Epoch 979/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6674
# Epoch 980/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6674
# Epoch 981/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6674
# Epoch 982/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6674
# Epoch 983/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6674
# Epoch 984/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6674
# Epoch 985/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6674
# Epoch 986/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6674
# Epoch 987/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6674
# Epoch 988/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6674
# Epoch 989/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6674
# Epoch 990/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6674
# Epoch 991/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6674
# Epoch 992/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6674
# Epoch 993/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6674
# Epoch 994/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6674
# Epoch 995/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6674
# Epoch 996/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6674
# Epoch 997/1000
# 3/3 [==============================] - 0s 2ms/sample - loss: 116.6674
# Epoch 998/1000
# 3/3 [==============================] - 0s 997us/sample - loss: 116.6674
# Epoch 999/1000
# 3/3 [==============================] - 0s 1ms/sample - loss: 116.6674
# Epoch 1000/1000
# 3/3 [==============================] - 0s 998us/sample - loss: 116.6674

# %%
print(t)
ypredict =model.predict(X)
print(ypredict)
model.summary(line_length=None, positions=None, print_fn=None)
# Out:
# [[ 4.]
#  [29.]
#  [ 9.]]
# [[13.999996]
#  [13.999922]
#  [13.999996]]
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_20 (Dense)             (None, 2)                 8
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 11
# Trainable params: 11
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Neural Networks

# %% [markdown]
# ## Structure of Neural Networks
#
# __The neuron__
#
# - The sigmoid equation is what is typically used as a transfer function between neurons. It is similar to the step function, but is continuous and differentiable.
#
# $$ \sigma(x) = \frac{1}{1+e^{-x}}$$
#
# - One useful property of this transfer function is the simplicity of computing its derivative.
#
# $$\frac{d}{dx}\sigma(x) = \sigma' = \sigma(x) (1-\sigma(x))$$
#
# __Single input neuron__
#
# <img src="./image_files/single_neuron.png" width = 300>
#
# $$ O = \sigma(\xi \omega + \theta) $$
#
# __Multiple input neuron__
#
# <img src="./image_files/multiple_neuron.png" width = 300>
#
# $$ O = \sigma(\xi_1 \omega_1 + \xi_2 \omega_2 + \xi_3 \omega_3 +\theta) $$
#
# __A neural network__
#
# <img src="./image_files/nn_03.png" width = 300>

# %% [markdown]
# # 2. Learning: Backpropagation Algorithm
#
# __Notation__
#
# - $x_j^\ell$: Input to node $j$ of layer $\ell$
#
# - $W_{ij}^\ell$: Weight from layer $\ell - 1$ node $i$ to layer $\ell$ node $j$
#
# - $\sigma(x) = \frac{1}{1+e^{-x}}$: Sigmoid transfer function
#
# - $\theta_j^{\ell}$: Bias of node $j$ of layer $\ell$
#
# - $O_j^{\ell}$: Output of node $j$ in layer $\ell$
#
# - $t_j$: Target value of node $j$ of the output layer
#
# <br>
# <font size='4'><b>The error calculation</b></font>
#
# Given a set of training data points $t_k$ and output layer output $O_k$ we can write the error as
#
# $$ E = \frac{1}{2} \sum_{k \in K} (O_k - t_k)^2$$
#
# We want to calculate $\frac{\partial E}{\partial W_{jk}^{\ell}}$, the rate of change of the error with respect to the given connective weight, so we can minimize it.
#
# Now we consider two cases: the node is an output node, or it is in a hidden layer
#
# __1) Output layer node__
#
# \begin{align*}
# \frac{\partial E}{\partial W_{jk}} &= \frac{\partial}{\partial W_{jk}} \frac{1}{2} (O_k - t_k)^2 = (O_k - t_k)\frac{\partial}{\partial W_{jk}} O_k = (O_k - t_k)\frac{\partial}{\partial W_{jk}} \sigma(x_k)\\
# &= (O_k - t_k) \sigma(x_k) (1-\sigma(x_k)) \frac{\partial}{\partial W_{jk}} x_k \\
# &= (O_k - t_k) O_k (1 - O_k) O_j
# \end{align*}
#
# $\quad$For notation purposes, I will define $\delta_k$ to be the expression $(O_k - t_k) O_k (1 - O_k)$, so we can rewrite the equation above as
#
# $$\frac{\partial E}{\partial W_{jk}} = O_j \delta_k $$
#
# __2) Hidden layer node__
#
# \begin{align*}
# \frac{\partial E}{\partial W_{ij}} &= \frac{\partial}{\partial W_{ij}} \frac{1}{2} \sum_{k \in K} (O_k - t_k)^2 = \sum_{k \in K} (O_k - t_k)\frac{\partial}{\partial W_{ij}} O_k = \sum_{k \in K} (O_k - t_k)\frac{\partial}{\partial W_{ij}} \sigma(x_k)\\
# &= \sum_{k \in K} (O_k - t_k) \sigma(x_k) (1-\sigma(x_k)) \frac{\partial}{\partial W_{ij}} x_k \\
# &= \sum_{k \in K} (O_k - t_k) O_k (1 - O_k) \frac{\partial x_k}{\partial O_j}\cdot \frac{\partial O_j}{\partial W_{ij}} = \sum_{k \in K} (O_k - t_k) O_k (1 - O_k) W_{jk}\cdot \frac{\partial O_j}{\partial W_{ij}}\\
# &= \frac{\partial O_j}{\partial W_{ij}} \cdot \sum_{k \in K} (O_k - t_k) O_k (1 - O_k) W_{jk}\\
# &= O_j (1-O_j)\frac{\partial x_j}{\partial W_{ij}} \cdot \sum_{k \in K} (O_k - t_k) O_k (1 - O_k) W_{jk}\\
# &= O_j (1-O_j)O_i \cdot \sum_{k \in K} (O_k - t_k) O_k (1 - O_k) W_{jk}\\
# &= O_i O_j (1-O_j) \sum_{k \in K} \delta_k W_{jk}
# \end{align*}
#
# $\quad$Similar to before we will now define all terms besides $O_i$ to be $\delta_j = O_j (1-O_j) \sum_{k \in K} \delta_k W_{jk}$, so we have
#
# $$\frac{\partial E}{\partial W_{ij}} = O_i \delta_j$$
#
#
# __How weights affect errors__
#
# - For an output layer node $k \in K$
#
# $$\frac{\partial E}{\partial W_{jk}} = O_j \delta_k $$
#
# $\quad \;\,$where $$\delta_k = (O_k - t_k) O_k (1 - O_k)$$
#
# - For a hidden layer node $j \in J$
#
# $$\frac{\partial E}{\partial W_{ij}} = O_i \delta_j$$
#
# $\quad \;\,$where $$\delta_j = O_j (1-O_j) \sum_{k \in K} \delta_k W_{jk}$$
#
# __What about the bias?__
#
# If we incorporate the bias term $\theta$ into the equation you will find that
#
# $$ \frac{\partial O}{\partial \theta} = 1$$
#
# This is why we view the bias term as output from a node which is always one. This holds for any layer $\ell$, a substitution into the previous equations gives us that
#
# $$ \frac{\partial E}{\partial \theta} = \delta_{\ell}$$
#
# <br>
# <font size='4'><b>The backpropagation algorithm using gradient descent</b></font>
#
# 1. Run the network forward with your input data to get the network output
#
# 2. For each output node compute
# $$\delta_k = (O_k - t_k) O_k (1 - O_k)$$
#
# 3. For each hidden node calculate
#
# $$\delta_j = O_j (1-O_j) \sum_{k \in K} \delta_k W_{jk}$$
#
# 4. Update the weights and biases as follows<br>
#
# Given
#
# \begin{align*}
# \Delta W &= -\eta \delta_{\ell} O_{\ell -1}\\
# \Delta \theta &= -\eta \delta_{\ell}
# \end{align*}
#
# apply
#
# \begin{align*}
# W &\leftarrow W + \Delta W \\
# \theta &\leftarrow \theta + \Delta \theta
# \end{align*}

# %%
# %%html
# <iframe src="https://www.youtube.com/embed/aVId8KMsdUU?list=PL29C61214F2146796"
# width="560" height="315" frameborder="0" allowfullscreen></iframe>
# Out:
# <iframe src="https://www.youtube.com/embed/aVId8KMsdUU?list=PL29C61214F2146796"
# width="560" height="315" frameborder="0" allowfullscreen></iframe>

# %%
# %%html
# <iframe src="https://www.youtube.com/embed/zpykfC4VnpM?list=PL29C61214F2146796"
# width="560" height="315" frameborder="0" allowfullscreen></iframe>
# Out:
# <iframe src="https://www.youtube.com/embed/zpykfC4VnpM?list=PL29C61214F2146796"
# width="560" height="315" frameborder="0" allowfullscreen></iframe>

# %% [markdown]
# # Implementation in python
#
# ## Resources
#
# - Ian Goodfellow, Yoshua Bengio, and Aaron Courville, [Deep Learning](http://www.deeplearningbook.org/), MIT Press, FREE online copy
#
# - Jason Brownlee **Deep Learning**, available in piazza for this course with codes in `Keras` and `Theano` libraries
#
# - [ml4a chapter on neural networks](http://ml4a.github.io/ml4a/neural_networks/).
#
# - Michael Nielsen's [Neural Networks and Deep Learning](http://neuralnetworksanddeeplearning.com/),
#
# - Yoav Goldberg's "[A Primer on Neural Network Models for Natural Language Processing](http://arxiv.org/abs/1510.00726)".
#
#
#
# For the other neural network guides we will mostly rely on the excellent [Keras](http://keras.io/) library, which makes it very easy to build neural networks and can take advantage of [Theano](http://deeplearning.net/software/theano/) or [TensorFlow](https://www.tensorflow.org/)'s optimizations and speed. However, to demonstrate the basics of neural networks, we'll use `numpy` so we can see exactly what's happening every step of the way.
#
# Each unit (neuron) has a vector of weights - these are the parameters that the network learns.
#
# The inner operations of the basic unit is straightforward. We collapse the weight vector $w$ and input vector $v$ into a scalar by taking their dot product. Often a _bias_ term $b$ is added to this dot product; this bias is also learned. then we pass this dot product through an _activation function_ $f$, which also returns a scalar. Activation functions are typically nonlinear so that neural networks can learn nonlinear functions. I'll mention a few common activation functions in a bit, but for now let's see what a basic unit is doing:
#
# ```python
# def unit(inputs, weights, b):
#     return activation_function(np.dot(inputs, weights) + b)
# ```
#
# Note that the output units often do not have an activation function.

# %% [markdown]
# ## 3.1. A basic neural network with `numpy`
#
# First we'll import `numpy`:

# %%
import numpy as np

# %% [markdown]
# With machine learning we are trying to find a hidden function that describes data that we have. Here we are going to cheat a little and define the function ourselves and then use that to generate data. Then we'll try to "reverse engineer" our data and see if we can recover our original function.

# %%
def unknown_function(X):
    coeff = np.array([[2., -1., 5.]])
    return np.dot(X, coeff.T)

X = np.array([
    [4.,9.,1.],
    [2.,5.,6.],
    [1.,8.,3.]
])

t = unknown_function(X) # target
print(t)
# Out:
# [[ 4.]
#  [29.]
#  [ 9.]]

# %% [markdown]
# Now we are going to set up our simple neural network. It will have just one hidden layer with two units (which we will refer to as unit 1 and unit 2).
#
# <img src="./image_files/simple_nn_structure.png" width = 250>
#
# First we have to define the weights (i.e. parameters) of our network.
#
# - We have three inputs each going into two units, then one bias value for each unit, so we have eight parameters for the hidden layer.
#
# - Then we have the output of those two hidden layer units going to the output layer, which has only one unit - this gives us two more parameters, plus one bias value.
#
# - So in total, we have eleven parameters.
#
# Let's set them to arbitrary values for now (random initialization).

# %%
# initial hidden layer weights
hidden_layer_weights = np.array([
    [0.5, 0.5, 0.5],    # unit 1
    [0.1, 0.1, 0.1]     # unit 2
])
hidden_layer_biases = np.array([1. ,1.])

# initial output layer weights
output_weights = np.array([[1., 1.]])
output_biases = np.array([1.])

# %% [markdown]
# We'll use $\tanh$ activations for our hidden units, so let's define that real quick:

# %%
def activation(X):
    return np.tanh(X)

# %% [markdown]
# $\tanh$ activations are quite common, but you may also encounter sigmoid activations and, more recently, ReLU activations (which output 0 when $x \leq 0$ and output $x$ otherwise). These activation functions have different benefits:
# - ReLUs in particular are robust against training difficulties that come when dealing with deeper networks.
#
# To make things clearer later on, we'll also define the linear function that combines a unit's input with its weights:

# %%
def linear(input, weights, biases):
    return np.dot(input, weights.T) + biases

# %% [markdown]
# Now we can do a forward pass with our inputs $X$ to see what the predicted outputs are.
#
# ## 3.2. Forward pass
#
# First, we'll pass the input through the hidden layer:

# %%
hidden_linout = linear(X, hidden_layer_weights, hidden_layer_biases)
hidden_output = activation(hidden_linout)

print('hidden_linout')
print(hidden_output)
# Out:
# hidden_linout
# [[ 0.99999978 -0.99905144]
#  [ 0.99999939  0.99961695]
#  [ 0.99999835 -0.60200848]]

# %% [markdown]
# (We're keeping the neuron unit's intermediary value, `hidden_linout` for use in backpropagation.)
#
# Then we'll take the hidden layer's output and pass it through the output layer to get our predicted outputs:

# %%
output_linout = linear(hidden_output, output_weights, output_biases)
output_output = output_linout # no activation function on output layer

predicted = output_output
print('predicted')
print(predicted)
# Out:
# predicted
# [[2.98367463]
#  [2.98009578]
#  [2.97574147]]

# %% [markdown]
# Now let's compute the mean squared error of our predictions:

# %%
mse = np.mean((t - predicted)**2)
print('mean squared error')
print(mse)
# Out:
# mean squared error
# 238.12000783695962

# %% [markdown]
# Now we can take this error and backpropagate it through the network. This will tell us how to update our weights.
#
# ## Backpropagation
#
# Since backpropagation is essentially a chain of derivatives (that is used for gradient descent), we'll need the derivative of our activation function, so let's define that first:

# %%
def activation_deriv(X):
    return 1 - np.tanh(X)**2

# %% [markdown]
# Then we want to set a learning rate - this is a value from 0 to 1 which affects how large we tweak our parameters by for each training iteration.
#
# - You don't want to set this to be too large or else training will never converge (your parameters might get really big and you'll start seeing a lot of `nan` values).
#
# - You don't want to set this to be too small either, otherwise training will be very slow. There are more sophisticated forms of gradient descent that deal with this, but those are beyond the scope of this guide.

# %%
learning_rate = 0.001

# %% [markdown]
# First we'll propagate the error through the output layer (I won't go through the derivation of each step but they are straightforward to work out if you know a bit about derivatives):

# %%
# derivative of mean squared error
error = predicted - t

# delta for the output layer (no activation on output layer)
delta_output = error

# output layer updates
output_weights_update = delta_output.T.dot(hidden_output)
output_biases_update = delta_output.sum(axis=0)

# %% [markdown]
# Then through the hidden layer:

# %%
# push back the delta to the hidden layer
delta_hidden = delta_output*output_weights*activation_deriv(hidden_linout)

# hidden layer updates
hidden_weights_update = delta_hidden.T.dot(X)
hidden_biases_update = delta_hidden.sum(axis=0)

# %% [markdown]
# Then we can apply the updates:

# %%
output_weights -= output_weights_update*learning_rate
output_biases -= output_biases_update*learning_rate

hidden_layer_weights -= hidden_weights_update*learning_rate
hidden_layer_biases -= hidden_biases_update*learning_rate

# %% [markdown]
# That's one training iteration! In reality, you would do this many, many times - feedforward, backpropagate, update weights, then rinse and repeat. That's the basics of a neural network - at least, the "vanilla" kind. There are other more sophisticated kinds (recurrent and convolutional neural networks are two of the most common) that are covered in other guides.

# %%
print (predicted)
# Out:
# [[2.98367463]
#  [2.98009578]
#  [2.97574147]]

# %% [markdown]
# ## Combine the above and iterate

# %%
# hidden layer weights
hidden_layer_weights = np.array([
    [0.5, 0.5, 0.5],    # unit 1
    [0.1, 0.1, 0.1]     # unit 2
])
hidden_layer_biases = np.array([1. ,1.])

# output layer weights
output_weights = np.array([[1., 1.]])
output_biases = np.array([1.])

for i in range(1000):
    
    hidden_linout = linear(X, hidden_layer_weights, hidden_layer_biases)
    hidden_output = activation(hidden_linout)
    
    output_linout = linear(hidden_output, output_weights, output_biases)
    output_output = output_linout # no activation function on output layer

    predicted = output_output

    # derivative of mean squared error
    error = predicted - t

    # delta for the output layer (no activation on output layer)
    delta_output = error

    # output layer updates
    output_weights_update = delta_output.T.dot(hidden_output)
    output_biases_update = delta_output.sum(axis = 0)

    # push back the delta to the hidden layer
    delta_hidden = delta_output*output_weights*activation_deriv(hidden_linout)

    # hidden layer updates
    hidden_weights_update = delta_hidden.T.dot(X)
    hidden_biases_update = delta_hidden.sum(axis = 0)

    output_weights -= output_weights_update*learning_rate
    output_biases -= output_biases_update*learning_rate

    hidden_layer_weights -= hidden_weights_update*learning_rate
    hidden_layer_biases -= hidden_biases_update*learning_rate

print (t)    
print (predicted)
# Out:
# [[ 4.]
#  [29.]
#  [ 9.]]
# [[ 5.53744024]
#  [26.56337057]
#  [ 7.75107771]]
